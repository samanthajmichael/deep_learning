# %% [markdown]
# # Assignment #1 - Deep Neural Network
#
# <font color="red"> <b> Due: Feb 22  11:59 pm </b> </font>

# %% [markdown]
# <font color="cyan"> SAMANTHA MICHAEL     </font>

# %% [markdown]
# # Introduction
#
# This project develops a Neural Network with Tensorflow to classify the cultural origin of pottery artifacts based on their characteristics from the [Ceramics: Temporal-Spatial Dataset](https://core.tdar.org/dataset/6039/ceramics-temporal-spatial-dataset) obtained from the [Digital Archeological Record (tDAR)](https://core.tdar.org/search/).
#
# The research aims to provide archaeologists with a computational tool that can aid in more efficiently categorizing and understanding past societies using deep learning techniques.

# %% [markdown]
# # Data

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', None)
dap = pd.read_csv('data/dap-tscer4.csv', low_memory=False)
dap.head()
# Out:
#   flag  site  fs area       subarea      sutype   sunum           suhoriz  \
# 0    E    23   2  NaN  Not assigned  GRID 4 X 4  312384  whole study unit
# 1    E    23   2  NaN  Not assigned  GRID 4 X 4  312384  whole study unit
# 2    E    23   2  NaN  Not assigned  GRID 4 X 4  312384  whole study unit
# 3    E    23   2  NaN  Not assigned  GRID 4 X 4  312384  whole study unit
# 4    E    23   3  NaN  Not assigned  GRID 4 X 4  316396  whole study unit
#
#            suvert  sugrid              susurf         sufap         sufat  \
# 0  not applicable       0  MODERN GROUND SURF  INAPPLICABLE  INAPPLICABLE
# 1  not applicable       0  MODERN GROUND SURF  INAPPLICABLE  INAPPLICABLE
# 2  not applicable       0  MODERN GROUND SURF  INAPPLICABLE  INAPPLICABLE
# 3  not applicable       0  MODERN GROUND SURF  INAPPLICABLE  INAPPLICABLE
# 4  not applicable       0  MODERN GROUND SURF  INAPPLICABLE  INAPPLICABLE
#
#          fetype  fenum  fehoriz          fevert         fefat  \
# 0  INAPPLICABLE      0      NaN  not applicable  INAPPLICABLE
# 1  INAPPLICABLE      0      NaN  not applicable  INAPPLICABLE
# 2  INAPPLICABLE      0      NaN  not applicable  INAPPLICABLE
# 3  INAPPLICABLE      0      NaN  not applicable  INAPPLICABLE
# 4  INAPPLICABLE      0      NaN  not applicable  INAPPLICABLE
#
#              collect  catno              pl    firing            temper  \
# 0  INTENSIVE SURFACE      4  No PL recorded   NEUTRAL  ANDESITE-DIORITE
# 1  INTENSIVE SURFACE      5  No PL recorded   NEUTRAL  ANDESITE-DIORITE
# 2  INTENSIVE SURFACE      6  No PL recorded  OXIDIZED  ANDESITE-DIORITE
# 3  INTENSIVE SURFACE      7  No PL recorded   NEUTRAL  ANDESITE-DIORITE
# 4  INTENSIVE SURFACE     10  No PL recorded   NEUTRAL  ANDESITE-DIORITE
#
#     manipul          compact cover pnttype color          cultcat  ware  \
# 0     PLAIN  UNPOLISHED-NONE  NONE    NONE  NONE   MESA V DOLORES  GRAY
# 1     PLAIN  UNPOLISHED-NONE  NONE    NONE  NONE   MESA V DOLORES  GRAY
# 2     PLAIN         POLISHED  NONE    NONE  NONE  MESA V BLANDING   RED
# 3  FILLETED  UNPOLISHED-NONE  NONE    NONE  NONE   MESA V DOLORES  GRAY
# 4     PLAIN  UNPOLISHED-NONE  NONE    NONE  NONE   MESA V DOLORES  GRAY
#
#              type  form  lotwt  lotcnt  rimcnt        modcnt     sphandl  \
# 0  MS-PRESPHENOID   JAR     17       6       6  INAPPLICABLE  UNASSIGNED
# 1     MS-PARIETAL   JAR    240      44       0  INAPPLICABLE  UNASSIGNED
# 2     MS-TEMPORAL  BOWL      3       2       0  INAPPLICABLE  UNASSIGNED
# 3  MS-ALISPHENOID   JAR     11       1       0  INAPPLICABLE  UNASSIGNED
# 4     MS-PARIETAL   JAR      4       1       0    ROUND FORM  UNASSIGNED
#
#            sstype  ssno                ccn                     ccc  \
# 0  NOT APPLICABLE     0  MCPHEE-GRASS MESA  Medium high confidence
# 1  NOT APPLICABLE     0  MCPHEE-GRASS MESA  Medium high confidence
# 2  NOT APPLICABLE     0  MCPHEE-GRASS MESA  Medium high confidence
# 3  NOT APPLICABLE     0  MCPHEE-GRASS MESA  Medium high confidence
# 4  NOT APPLICABLE     0  MCPHEE-GRASS MESA  Medium high confidence
#
#                      cci  rn              rc                ri  ihn  \
# 0  Medium high integrity   0  Not applicable  Lowest integrity    0
# 1  Medium high integrity   0  Not applicable  Lowest integrity    0
# 2  Medium high integrity   0  Not applicable  Lowest integrity    0
# 3  Medium high integrity   0  Not applicable  Lowest integrity    0
# 4  Medium high integrity   0  Not applicable  Lowest integrity    0
#
#               ihc               ihi  hn              hc                hi  \
# 0  Not applicable  Lowest integrity   0  Not applicable  Lowest integrity
# 1  Not applicable  Lowest integrity   0  Not applicable  Lowest integrity
# 2  Not applicable  Lowest integrity   0  Not applicable  Lowest integrity
# 3  Not applicable  Lowest integrity   0  Not applicable  Lowest integrity
# 4  Not applicable  Lowest integrity   0  Not applicable  Lowest integrity
#
#               uat  uan             uac               uai             aat  aan  \
# 0  NOT APPLICABLE    0  Not applicable  Lowest integrity  NOT APPLICABLE    0
# 1  NOT APPLICABLE    0  Not applicable  Lowest integrity  NOT APPLICABLE    0
# 2  NOT APPLICABLE    0  Not applicable  Lowest integrity  NOT APPLICABLE    0
# 3  NOT APPLICABLE    0  Not applicable  Lowest integrity  NOT APPLICABLE    0
# 4  NOT APPLICABLE    0  Not applicable  Lowest integrity  NOT APPLICABLE    0
#
#               aac             aai                eef  een             eec  \
# 0  Not applicable  Not applicable  Unrecognized code    0  Not applicable
# 1  Not applicable  Not applicable  Unrecognized code    0  Not applicable
# 2  Not applicable  Not applicable  Unrecognized code    0  Not applicable
# 3  Not applicable  Not applicable  Unrecognized code    0  Not applicable
# 4  Not applicable  Not applicable  Unrecognized code    0  Not applicable
#
#                 eei       tn                  tc                 ti      pn  \
# 0  Lowest integrity  ANASAZI  Highest confidence  Highest integrity  MCPHEE
# 1  Lowest integrity  ANASAZI  Highest confidence  Highest integrity  MCPHEE
# 2  Lowest integrity  ANASAZI  Highest confidence  Highest integrity  MCPHEE
# 3  Lowest integrity  ANASAZI  Highest confidence  Highest integrity  MCPHEE
# 4  Lowest integrity  ANASAZI  Highest confidence  Highest integrity  MCPHEE
#
#                        pc                     pi            spn  \
# 0  Medium high confidence  Medium high integrity  INAPPPLICABLE
# 1  Medium high confidence  Medium high integrity  INAPPPLICABLE
# 2  Medium high confidence  Medium high integrity  INAPPPLICABLE
# 3  Medium high confidence  Medium high integrity  INAPPPLICABLE
# 4  Medium high confidence  Medium high integrity  INAPPPLICABLE
#
#               spc               spi   mpn1                    mpc1  \
# 0  Not applicable  Lowest integrity  MP IV  Medium high confidence
# 1  Not applicable  Lowest integrity  MP IV  Medium high confidence
# 2  Not applicable  Lowest integrity  MP IV  Medium high confidence
# 3  Not applicable  Lowest integrity  MP IV  Medium high confidence
# 4  Not applicable  Lowest integrity  MP IV  Medium high confidence
#
#              mpc2                st1  st2               stc1            stc2  \
# 0  Not applicable  Unrecognized code    0  Unrecognized code  Not applicable
# 1  Not applicable  Unrecognized code    0  Unrecognized code  Not applicable
# 2  Not applicable  Unrecognized code    0  Unrecognized code  Not applicable
# 3  Not applicable  Unrecognized code    0  Unrecognized code  Not applicable
# 4  Not applicable  Unrecognized code    0  Unrecognized code  Not applicable
#
#            mpn          sittype  mpnew              cobjectid csiteid  \
# 0  MPIV OR MPV  HABITATION, NFS  OTHER   78.1.5MT23.CER.2.4.0   5MT23
# 1  MPIV OR MPV  HABITATION, NFS  OTHER   78.1.5MT23.CER.2.5.0   5MT23
# 2  MPIV OR MPV  HABITATION, NFS  OTHER   78.1.5MT23.CER.2.6.0   5MT23
# 3  MPIV OR MPV  HABITATION, NFS  OTHER   78.1.5MT23.CER.2.7.0   5MT23
# 4  MPIV OR MPV  HABITATION, NFS  OTHER  78.1.5MT23.CER.3.10.0   5MT23
#
#    caccnid cdept
# 0     78.1   CER
# 1     78.1   CER
# 2     78.1   CER
# 3     78.1   CER
# 4     78.1   CER

# %%
dap.isna().sum()
# Out:
# flag             0
# site             0
# fs               0
# area         70693
# subarea      30168
# sutype           0
# sunum            0
# suhoriz       1769
# suvert           0
# sugrid           0
# susurf           0
# sufap            0
# sufat            0
# fetype           0
# fenum            0
# fehoriz      81603
# fevert        5704
# fefat            0
# collect          0
# catno            0
# pl           12613
# firing           0
# temper           0
# manipul          0
# compact          0
# cover            0
# pnttype          0
# color            0
# cultcat          0
# ware             0
# type             0
# form             0
# lotwt            0
# lotcnt           0
# rimcnt           0
# modcnt           0
# sphandl          0
# sstype           0
# ssno             0
# ccn            220
# ccc              0
# cci              0
# rn               0
# rc               0
# ri               0
# ihn              0
# ihc              0
# ihi              0
# hn               0
# hc               0
# hi               0
# uat              0
# uan              0
# uac              0
# uai              0
# aat              0
# aan              0
# aac              0
# aai              0
# eef              0
# een              0
# eec              0
# eei              0
# tn               0
# tc               0
# ti               0
# pn               0
# pc               0
# pi               0
# spn              0
# spc              0
# spi              0
# mpn1             0
# mpc1             0
# mpc2             0
# st1              0
# st2              0
# stc1             0
# stc2             0
# mpn              0
# sittype          0
# mpnew            0
# cobjectid        0
# csiteid          0
# caccnid          0
# cdept            0
# dtype: int64

# %% [markdown]
# ### High number of nulls:
#
# * area - 70,693 nulls
# * subarea - 30,168 nulls
# * suhoriz - 1,769 nulls
# * fehoriz (Feature horizontal) - 81,603 nulls
# * fevert  (Vertical excavation position)
# * pl (Point Location) - 12,613 nulls

# %% [markdown]
# #### Dropping the Features with the highest number of nulls
#
# * area
# * subarea
# * suhoriz - 1,769 nulls - not as concerning since this is only around 2% of the data - this feature is about excavation methodology rather than a characteristic of the pottery and will be dropped.
# * fehoriz (Feature horizontal) - 81,603 nulls
# * fevert  (Vertical excavation position) - 5,704 nulls - this is less concerning since this feature describes the depth of the archeological find. This could be a good predictor of the cultural category since the higher the depth of the find could correlate to the age / time period of the pottery.
# * pl

# %% [markdown]
# ### Revelant Features

# %%
dap = dap[['firing', 'temper', 'manipul', 'compact', 'color', 'pnttype', 'cover', 'ware', 'form', 'fevert', 'cultcat']]

# %% [markdown]
# | Feature | Description |
# |---------|-------------|
# | firing | Firing atmosphere |
# | temper | Type of temper used |
# | manipul | Surface manipulation |
# | compact | Surface compaction |
# | color | Paint colors used |
# | pnttype | Paint type (organic, mineral, clay) |
# | cover | Surface slips/coatings |
# | ware | Manufacturing technique groups |
# | form | Vessel shape/type |
# |culcat|Cultural Category|

# %%
dap.dtypes
# Out:
# firing     object
# temper     object
# manipul    object
# compact    object
# color      object
# pnttype    object
# cover      object
# ware       object
# form       object
# fevert     object
# cultcat    object
# dtype: object

# %%
dap.isna().sum()
# Out:
# firing        0
# temper        0
# manipul       0
# compact       0
# color         0
# pnttype       0
# cover         0
# ware          0
# form          0
# fevert     5704
# cultcat       0
# dtype: int64

# %%
dap.describe().T
# Out:
#          count unique               top   freq
# firing   81603      7           NEUTRAL  58789
# temper   81603     32  ANDESITE-DIORITE  64690
# manipul  81603     10             PLAIN  68736
# compact  81603      5   UNPOLISHED-NONE  54616
# color    81603     10              NONE  65060
# pnttype  81603      9              NONE  65060
# cover    81603      5              NONE  76580
# ware     81603      8              GRAY  52060
# form     81603     32               JAR  55838
# fevert   75899     23    not applicable  73414
# cultcat  81603     13    MESA V DOLORES  56571

# %%
features = ['firing', 'temper', 'manipul', 'compact', 'color', 'pnttype', 'cover', 'ware', 'form', 'fevert', 'cultcat']
for feature in features: 
    print(dap[feature].value_counts())
    print("-" * 50)
# Out:
# firing
# NEUTRAL          58789
# OXIDIZED         12680
# REFIRED           6488
# VITRIFIED         3302
# UNFIRED            271
# SMUDGED             69
# INDETERMINATE        4
# Name: count, dtype: int64
# --------------------------------------------------
# temper
# ANDESITE-DIORITE        64690
# SJ CRUSHED ROCK          6744
# SHERD A-D                1340
# SAND-MULTILITHIC         1168
# CONGLOM                  1153
# SHERD AND SJ             1046
# DAKOTA SANDSTN           1025
# SAND-QUARTZ               753
# SAND A-D                  691
# DRK ANDESITE DIORITE      627
# INDETERMINATE             447
# TRACHY BASALT             324
# DARK MATRIX SANDSTN       321
# NONE                      291
# COMBINED                  251
# SHERD-QRTZ SAND           154
# SHERD                     117
# SANDSTONE                 114
# SALMON SANDSTN            100
# SANDSTN W-HEM              66
# LA PLATA                   59
# SHERD AND SANDSTN          32
# CRUSHED QTZ-SAND           24
# SHERD CONGLOMER            23
# SHERD A-D SAND             23
# MULTLIT SND-SHD             7
# NOT APPLICABLE              5
# TRCHY-BSLT W-HEM            2
# MICA                        2
# FINE SJ CRUSHED             2
# STAINED QUARTZ              1
# SHERD TRCHY BSLT            1
# Name: count, dtype: int64
# --------------------------------------------------
# manipul
# PLAIN             68736
# FILLETED           6924
# CLAPBOARDED        2717
# CORRUGATED         1649
# COILED              712
# INCISED             338
# NOT APPLICABLE      220
# PERFORATED          198
# OTHER                97
# INDETERMINATE        12
# Name: count, dtype: int64
# --------------------------------------------------
# compact
# UNPOLISHED-NONE    54616
# POLISHED           26754
# NOT APPLICABLE       222
# INDETERMINATE         10
# OTHER                  1
# Name: count, dtype: int64
# --------------------------------------------------
# color
# NONE                 65060
# BROWN TO BLACK       13804
# ORANGE TO RED         2340
# NOT APPLICABLE         230
# PT COLORS              104
# INDETERMINATE           27
# COMBINATION             22
# OTHER                    8
# WHITE                    7
# Unrecognized code        1
# Name: count, dtype: int64
# --------------------------------------------------
# pnttype
# NONE                  65060
# MIN PAINT ONLY         8597
# MIN PAINT W-BINDER     6854
# ORG PAINT ONLY          702
# NOT APPLICABLE          223
# GLAZE PAINT             119
# INDETERMINATE            35
# MULTIPLE PAINT           11
# CLAY PAINT ONLY           2
# Name: count, dtype: int64
# --------------------------------------------------
# cover
# NONE              76580
# SLIPPED-WASHED     3596
# FUGITIVE RED       1187
# NOT APPLICABLE      223
# INDETERMINATE        17
# Name: count, dtype: int64
# --------------------------------------------------
# ware
# GRAY              52060
# WHITE             15113
# RED               14119
# NOT APPLICABLE      218
# SMUDGED              48
# BROWN                29
# INDETERMINATE        12
# YELLOW                4
# Name: count, dtype: int64
# --------------------------------------------------
# form
# JAR                 55838
# BOWL                21472
# JAR HANDLE            910
# SEED JAR              894
# MINIATURE VESSEL      567
# OTHER HANDLE          336
# LUG HANDLE            316
# INDETERMINATE         230
# NOT APPLICABLE        217
# BOWL DIPPER           136
# OPEN GOURD            132
# GOURD JAR             101
# EFFIGY                 81
# OTHER                  71
# BOWL DIPPER HNDL       57
# PINCH                  40
# BEAKER                 33
# JAR APPLIQUE           32
# PIPE                   26
# INDET-NOT VESSEL       22
# APPLIQUE               22
# FEATHER BOX            19
# INTERIOR HANDLE        13
# BALL                    8
# CONE                    5
# FIGURINE                5
# BILOBE                  4
# PERF PINCH              4
# BASKET LINER            4
# BEAD                    4
# MUG                     3
# KIVA JAR                1
# Name: count, dtype: int64
# --------------------------------------------------
# fevert
# not applicable    73414
# level 1             703
# surface 1           577
# stratum 1           302
# stratum 2           200
# level 2             130
# stratum 3           113
# level 3              93
# stratum 5            80
# level 4              75
# level 5              58
# level 6              48
# level 7              35
# stratum 4            17
# stratum 7            16
# level 10             13
# stratum 6            11
# level 9               5
# stratum 14            3
# stratum 21            3
# stratum 11            1
# stratum 12            1
# stratum 22            1
# Name: count, dtype: int64
# --------------------------------------------------
# cultcat
# MESA V DOLORES      56571
# MESA V BLANDING     14050
# MESA V SAN JUAN      5386
# MESA V CAHONE        2199
# MESA V SANDSTONE     1306
# QRTZ SAND IND         640
# INDETERMINATE         549
# CIBOLA                351
# CHUSKA                328
# KAYENTA               136
# MESA V ANIMAS          58
# MOGOLLON               28
# SHOSHONE                1
# Name: count, dtype: int64
# --------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
features = ['firing', 'temper', 'manipul', 'compact', 'color', 'pnttype', 'cover', 'ware', 'form']
for ax, feature in zip(axes.ravel(), features):
    sns.countplot(data=dap, y=feature, order=dap[feature].value_counts().index, ax=ax)
    ax.set_title(f'Distribution of {feature}')
plt.tight_layout()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=dap, y='cultcat', order=dap['cultcat'].value_counts().index)
plt.title('Distribution of Cultural Categories (Labels)')
# Out:
# Text(0.5, 1.0, 'Distribution of Cultural Categories (Labels)')

# %% [markdown]
# ### Feature Distributions
# #### Observations:
#
# Potentially Problematic:
#
# * cover: 76,580/81,604 are "none" (~94%)
# * color: 65,060/81,604 are "none" (~80%) - one color is 'unrecognized code'
# * pnttype: 65,060/81,604 are "none" (~80%)
# * fevert: 73,414/81,604 are "not applicable" (~90%)
# * cultcat: 549/81,604 are "indeterminate" - these should be dropped
#
# More Balanced/Informative:
#
# * firing: Good distribution between NEUTRAL (58,789) and others
# * ware: Well distributed between GRAY (52,060), WHITE (15,113), RED (14,119)
# * form: Good variety with JAR (55,838) and BOWL (21,472) dominating
# * temper: Rich variety with ANDESITE-DIORITE (64,690) dominant
# * manipul: Dominated by PLAIN (68,736) but has meaningful variation
# * compact: Binary-like between UNPOLISHED-NONE (54,616) and POLISHED (26,754)

# %% [markdown]
# Decisions to Keep or Drop Problematic Variables:
#
# * Dropping fevert since this variable unfortunately does not contain any information for our analysis
# * Keeping cover as this refers to slip type. Not all pottery requires a slip
# * Keeping pnttype since not all pottery is painted
# * Keeping color because this refers to the paint type
# * Remove "OTHER" from compact, color, and manipul since these are very few instances and we don't know what they represent
# * Keep "OTHER HANDLE" in form because it's a specific subcategory of handles, not a catch-all "OTHER"
# * Keeping "OTHER" in form since it might represent legitimate vessel forms that just didn't fit the main categories

# %% [markdown]
# ### Removing Variables and Filtering Rows

# %%
dap = dap.drop(columns={'fevert'}, axis=1)

remove_values = ['INDETERMINATE', 'NOT APPLICABLE', 'Unrecognized code']
feature_columns = ['firing', 'temper', 'manipul', 'compact', 'color', 'pnttype', 'cover', 'ware', 'form', 'cultcat']

for col in feature_columns:
    dap = dap[~dap[col].isin(remove_values)]

columns_to_remove_other = ['compact', 'color', 'manipul']
for col in columns_to_remove_other:
    dap = dap[dap[col] != 'OTHER']

dap_df = dap.copy(deep=True)
X = dap_df.drop('cultcat', axis=1)
y = dap_df['cultcat']

# %% [markdown]
# ### Class Label Distributions
#
# |Class Labels|Instances|
# |-----|----|
# |MESA V DOLORES|      56,571|
# |MESA V BLANDING|     14,050|
# |MESA V SAN JUAN|      5,386|
# |MESA V CAHONE|        2,199|
# |MESA V SANDSTONE|     1,306|
# |QRTZ SAND IND|         640|
# |INDETERMINATE|         549|
# |CIBOLA|                351|
# |CHUSKA|                328|
# |KAYENTA|               136|
# |MESA V ANIMAS|          58|
# |MOGOLLON|               28|
# |SHOSHONE|                1|

# %% [markdown]
# ### Dealing with Imbalanced Classes
# * Mesa Verde variants dominate the dataset (Mesa V Dolores: 56,571, Mesa V Blanding: 14,050 etc...)
# * Very few instances of some cultures (Shoshone: 1, Mogollon: 28, Mesa V Animas: 58)

# %% [markdown]
# ### Filtering out Severely Underrepresented Class Labels
# * Choosing to drop class labels with less than 100 instances and use SMOTE to rebalance the classes

# %%
min_samples = 100
class_counts = y.value_counts()
valid_classes = class_counts[class_counts >= min_samples].index
mask = y.isin(valid_classes)
X_filtered = X[mask]
y_filtered = y[mask]

# %% [markdown]
# ### Dummy Encoding all Categorical Variables

# %%
X_encoded = pd.get_dummies(X_filtered, dtype=int)
# using LabelEncoder instead of get_dummies for y
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_encoded = le.fit_transform(y_filtered)

# %%
#y_encoded.columns

# %%
#X_encoded.columns

# %% [markdown]
# ### Applying Synthetic Minority Over-sampling Technique (SMOTE) to Correct for Imbalanced Classes

# %%
from imblearn.over_sampling import SMOTE
# convert to numpy arrays
X_array = X_encoded.to_numpy()
y_array = y_encoded ## this is alrady a numpy array
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X_array, y_array)

# %%
print("Original shapes:", X_array.shape, y_array.shape)
print("After SMOTE:", X_smote.shape, y_smote.shape)
# Out:
# Original shapes: (80317, 95) (80317,)
# After SMOTE: (504324, 95) (504324,)

# %%
print("\nClass distribution after SMOTE:")
print(pd.Series(y_smote).value_counts())
# Out:
# Class distribution after SMOTE:
# 5    56036
# 3    56036
# 7    56036
# 4    56036
# 6    56036
# 2    56036
# 8    56036
# 0    56036
# 1    56036
# Name: count, dtype: int64

# %%
# save the data into numpy arrays
np.save('data/X_smote.npy', X_smote)
np.save('data/y_smote.npy', y_smote)

# save the label encoder
import pickle
import numpy as np
# save encoder
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)

# %% [markdown]
# # References
#
# Digital Archaeological Record. (1988). Ceramics: Temporal-Spatial Dataset (tDAR id: 6039). https://doi.org/10.6067/XCV8TD9WNB

# %% [markdown]
# ## Grading
#
# DO NOT forget to submit your data! Your notebook is supposed to run well after running your codes.
#
# ** Note: this is a WRITING assignment. Proper writing is REQUIRED. Comments are not considered as writing. **
#
#
# Points | | Description
# --|--|:--
# 5 | Introduction
# 20 | Data |
#  | 5| description
#  | 5| plots for understanding or analysis
#  | 5| preliminary observation
#  | 5| Preprocessing of the data
# 40 | Method |
#  | 10| Explanation of deep network architecture and choice of components
#  | 10| explanation of codes
#  | 20| Correct implementation/Preliminary Test
# 30 | Experiments |
#  | 5| description, codes
#  | 10| visualization of results
#  | 15| analysis & retesting if need
# 5 | Conclusions, References
